# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
import glob
import pandas as pd
#import mitosheet
#mitosheet.sheet()

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
us_census.columns
us_census.dtypes

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head()

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
us_census.Income = us_census.Income.str.replace("[$,]", "")
us_census.Income = pd.to_numeric(us_census.Income)
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2332581216.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Income = us_census.Income.str.replace("[$,]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2332581216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_census.Income = us_census.Income.str.replace("[$,]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2332581216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us_census.Income = pd.to_numeric(us_census.Income)

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
us_census["split"] = us_census["GenderPop"].str.split("_")
us_census["Women"] = us_census.split.str.get(1)
us_census["Men"] = us_census.split.str.get(0)
us_census = us_census[["State", "TotalPop", "Hispanic", "White", "Black", "Native", "Asian",\
                "Pacific", "Income", "GenderPop", "Women", "Men"]]
us_census.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#      Income            GenderPop      Women        Men
# 0  43296.36    2341093M_2489527F   2489527F   2341093M
# 1  70354.74      384160M_349215F    349215F    384160M
# 2  54207.82    3299088M_3342840F   3342840F   3299088M
# 3  41935.63    1451913M_1506295F   1506295F   1451913M
# 4  67264.78  19087135M_19334329F  19334329F  19087135M

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
us_census.Women = us_census.Women.str.replace("[F]", "")
us_census.Men = us_census.Men.str.replace("[M]", "")
us_census.Women = pd.to_numeric(us_census.Women)
us_census.Men = pd.to_numeric(us_census.Men)

us_census.head()
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2544013359.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Women = us_census.Women.str.replace("[F]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2544013359.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Men = us_census.Men.str.replace("[M]", "")
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#      Income            GenderPop       Women       Men
# 0  43296.36    2341093M_2489527F   2489527.0   2341093
# 1  70354.74      384160M_349215F    349215.0    384160
# 2  54207.82    3299088M_3342840F   3342840.0   3299088
# 3  41935.63    1451913M_1506295F   1506295.0   1451913
# 4  67264.78  19087135M_19334329F  19334329.0  19087135

# %%
us_census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income       float64
# GenderPop     object
# Women        float64
# Men            int64
# dtype: object

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
plt.scatter(us_census.Women, us_census.Men)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
us_census = us_census.fillna(value = {"Women":us_census.Women.mean()})
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      60 non-null     object
#  1   TotalPop   60 non-null     int64
#  2   Hispanic   60 non-null     object
#  3   White      60 non-null     object
#  4   Black      60 non-null     object
#  5   Native     60 non-null     object
#  6   Asian      60 non-null     object
#  7   Pacific    55 non-null     object
#  8   Income     60 non-null     float64
#  9   GenderPop  60 non-null     object
#  10  Women      60 non-null     float64
#  11  Men        60 non-null     int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 6.1+ KB

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
us_census.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census.drop_duplicates()
# Out:
#                   State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0               Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1                Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2               Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3              Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4            California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
# 5              Colorado   5278906   20.78%  69.90%   3.55%   0.57%   2.66%
# 1           Connecticut   3593222   15.60%  67.68%  10.35%   0.13%   4.02%
# 2              Delaware    926454    8.82%  64.63%  20.74%   0.26%   3.27%
# 3  District of Columbia    647484    9.17%  33.10%  51.78%   0.20%   3.38%
# 4               Florida  19645772   21.34%  59.08%  15.17%   0.21%   2.28%
# 5               Georgia  10006693    8.42%  54.29%  32.09%   0.19%   3.10%
# 1                Hawaii   1406299    9.19%  25.03%   2.05%   0.14%  36.59%
# 2                 Idaho   1616547   11.51%  83.14%   0.57%   1.47%   1.14%
# 3              Illinois  12873761   15.60%  60.86%  17.11%   0.12%   4.48%
# 4               Indiana   6568645    6.54%  78.43%  11.19%   0.19%   1.58%
# 5                  Iowa   3093526    5.30%  87.72%   3.26%   0.29%   1.70%
# 1                Kansas   2892987   11.64%  75.96%   6.57%   0.73%   2.33%
# 2              Kentucky   4397353    3.22%  85.23%   8.27%   0.17%   1.13%
# 3             Louisiana   4625253    4.87%  54.98%  36.33%   0.48%   1.67%
# 4                 Maine   1329100    1.43%  93.71%   1.13%   0.79%   0.97%
# 5              Maryland   5930538    8.47%  52.68%  30.68%   0.20%   5.33%
# 1         Massachusetts   6705586   11.46%  73.04%   6.83%   0.13%   5.84%
# 2              Michigan   9900571    4.63%  72.38%  17.63%   0.48%   2.42%
# 3             Minnesota   5419171    5.15%  81.43%   5.66%   1.07%   4.16%
# 4           Mississippi   2988081    2.84%  53.29%  41.49%   0.39%   0.88%
# 5              Missouri   6045448    4.04%  77.51%  14.12%   0.36%   1.62%
# 1               Montana   1014699    3.27%  86.42%   0.43%   7.06%   0.57%
# 2              Nebraska   1869365    9.20%  81.14%   4.96%   0.86%   1.86%
# 3                Nevada   2798636   27.10%  53.24%   7.74%   1.09%   7.10%
# 4         New Hampshire   1324201    3.32%  91.32%   1.23%   0.14%   2.19%
# 5            New Jersey   8904413   18.75%  56.49%  14.39%   0.12%   8.16%
# 1            New Mexico   2084117   45.28%  40.70%   1.76%   9.25%   1.23%
# 2              New York  19673174   17.24%  56.47%  15.67%   0.32%   7.90%
# 3        North Carolina   9845333    8.46%  64.60%  21.40%   1.09%   2.32%
# 4          North Dakota    721640    2.83%  87.45%   1.28%   5.65%   0.96%
# 5                  Ohio  11575977    3.67%  75.90%  16.21%   0.17%   1.62%
# 1              Oklahoma   3849733   10.08%  66.06%   8.31%   6.72%   1.80%
# 2                Oregon   3939233   11.44%  78.40%   1.73%   1.00%   3.59%
# 3          Pennsylvania  12779559    6.13%  77.38%  11.63%   0.12%   2.80%
# 4           Puerto Rico   3583073   98.89%   0.77%   0.09%   0.00%   0.08%
# 5          Rhode Island   1053661   13.36%  74.33%   5.68%   0.35%   3.25%
# 1        South Carolina   4777576    5.06%  62.89%  28.75%   0.29%   1.25%
# 2          South Dakota    843190    3.24%  82.50%   1.42%   9.42%   1.02%
# 3             Tennessee   6499615    4.72%  73.49%  18.28%   0.23%   1.41%
# 4                 Texas  26538614   38.05%  44.69%  11.65%   0.26%   3.67%
# 5                  Utah   2903379   13.47%  79.41%   1.02%   1.08%   2.20%
# 1               Vermont    626604    1.61%  93.98%   0.98%   0.30%   1.24%
# 2              Virginia   8256630    8.01%  63.27%  20.18%   0.21%   5.46%
# 3            Washington   6985464   11.14%  72.04%   3.38%   1.41%   7.02%
# 4         West Virginia   1851420    1.29%  92.18%   3.66%   0.15%   0.68%
# 5             Wisconsin   5742117    6.68%  79.86%   8.20%   0.95%   2.40%
#
#   Pacific    Income            GenderPop         Women       Men
# 0   0.03%  43296.36    2341093M_2489527F  2.489527e+06   2341093
# 1   1.06%  70354.74      384160M_349215F  3.492150e+05    384160
# 2   0.17%  54207.82    3299088M_3342840F  3.342840e+06   3299088
# 3   0.15%  41935.63    1451913M_1506295F  1.506295e+06   1451913
# 4   0.35%  67264.78  19087135M_19334329F  1.933433e+07  19087135
# 5     NaN  64657.80    2648667M_2630239F  2.630239e+06   2648667
# 1   0.02%  76146.56    1751607M_1841615F  1.841615e+06   1751607
# 2     NaN  61827.98      448413M_478041F  4.780410e+05    448413
# 3   0.03%  75466.36      306674M_340810F  3.408100e+05    306674
# 4   0.05%  50690.19   9600009M_10045763F  1.004576e+07   9600009
# 5   0.05%  50811.08    4883331M_5123362F  5.123362e+06   4883331
# 1   8.76%  73264.43      709871M_696428F  6.964280e+05    709871
# 2   0.13%  48017.32      810464M_806083F  8.060830e+05    810464
# 3   0.02%  59587.05    6316899M_6556862F  6.556862e+06   6316899
# 4   0.03%  48616.23    3235263M_3333382F  3.333382e+06   3235263
# 5   0.06%  53017.75    1534595M_1558931F  1.558931e+06   1534595
# 1     NaN  53885.61    1439862M_1453125F  1.453125e+06   1439862
# 2   0.05%  45285.80    2164208M_2233145F  2.233145e+06   2164208
# 3   0.04%  44957.99    2261156M_2364097F  2.364097e+06   2261156
# 4   0.02%  49181.97      650081M_679019F  6.790190e+05    650081
# 5   0.04%  78765.40           2872643M_F  3.222093e+06   2872643
# 1   0.02%  72838.94    3249650M_3455936F  3.455936e+06   3249650
# 2   0.02%  51201.83    4861973M_5038598F  5.038598e+06   4861973
# 3   0.03%  62820.83    2692166M_2727005F  2.727005e+06   2692166
# 4   0.02%  38909.92    1451723M_1536358F  1.536358e+06   1451723
# 5   0.10%  49763.99    2964003M_3081445F  3.081445e+06   2964003
# 1   0.07%  47645.68            510163M_F  3.222093e+06    510163
# 2   0.06%  55916.47      929606M_939759F  9.397590e+05    929606
# 3   0.57%  55526.53    1407735M_1390901F  1.390901e+06   1407735
# 4   0.02%  68728.86      653484M_670717F  6.707170e+05    653484
# 5   0.03%  76581.08    4343027M_4561386F  4.561386e+06   4343027
# 1   0.04%  47329.97    1032414M_1051703F  1.051703e+06   1032414
# 2   0.02%  64290.75   9541801M_10131373F  1.013137e+07   9541801
# 3   0.05%  49937.46    4795408M_5049925F  5.049925e+06   4795408
# 4     NaN  58188.11      367963M_353677F  3.536770e+05    367963
# 5   0.02%  49655.25    5662893M_5913084F  5.913084e+06   5662893
# 1   0.11%  48100.85    1906944M_1942789F  1.942789e+06   1906944
# 2   0.35%  54271.90    1948453M_1990780F  1.990780e+06   1948453
# 3   0.02%  56170.46    6245344M_6534215F  6.534215e+06   6245344
# 4   0.00%  20720.54    1713860M_1869213F  1.869213e+06   1713860
# 5   0.04%  59125.27      510388M_543273F  5.432730e+05    510388
# 1   0.05%  46296.81    2322409M_2455167F  2.455167e+06   2322409
# 2   0.04%  51805.41      423477M_419713F  4.197130e+05    423477
# 3   0.04%  47328.08    3167756M_3331859F  3.331859e+06   3167756
# 4   0.07%  55874.52  13171316M_13367298F  1.336730e+07  13171316
# 5   0.83%  63488.92    1459229M_1444150F  1.444150e+06   1459229
# 1   0.03%  55602.97      308573M_318031F  3.180310e+05    308573
# 2   0.06%  72866.01    4060948M_4195682F  4.195682e+06   4060948
# 3   0.61%  64493.77    3487725M_3497739F  3.497739e+06   3487725
# 4   0.03%  41437.11      913631M_937789F  9.377890e+05    913631
# 5   0.02%  53898.89    2851385M_2890732F  2.890732e+06   2851385

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.scatter(us_census.Women, us_census.Men)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'Women', 'Men'],
#       dtype='object')

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
us_census.Hispanic = us_census.Hispanic.str.replace("[%]", "")
us_census.Hispanic = pd.to_numeric(us_census.Hispanic)
us_census.White = us_census.White.str.replace("[%]", "")
us_census.White = pd.to_numeric(us_census.White)
us_census.Black = us_census.Black.str.replace("[%]", "")
us_census.Black = pd.to_numeric(us_census.Black)
us_census.Native = us_census.Native.str.replace("[%]", "")
us_census.Native = pd.to_numeric(us_census.Native)
us_census.Pacific = us_census.Pacific.str.replace("[%]", "")
us_census.Pacific = pd.to_numeric(us_census.Pacific)
us_census.Asian = us_census.Asian.str.replace("[%]", "")
us_census.Asian = pd.to_numeric(us_census.Asian)
# Out:
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Hispanic = us_census.Hispanic.str.replace("[%]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.White = us_census.White.str.replace("[%]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Black = us_census.Black.str.replace("[%]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Native = us_census.Native.str.replace("[%]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Pacific = us_census.Pacific.str.replace("[%]", "")
# C:\Users\Gleb\AppData\Local\Temp\ipykernel_15492\2380088897.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   us_census.Asian = us_census.Asian.str.replace("[%]", "")

# %%
plt.hist(us_census.Hispanic)
plt.hist(us_census.White)
plt.hist(us_census.Black)
plt.hist(us_census.Native)
plt.hist(us_census.Asian)
plt.hist(us_census.Pacific)
plt.show()

# %% [markdown]
# ## Get Creative

# %% [markdown]
# 15. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.

# %%
us_census.to_csv("us_census_full.csv")
